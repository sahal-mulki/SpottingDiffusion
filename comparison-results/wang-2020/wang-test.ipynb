# %%
# !git clone https://github.com/PeterWang512/CNNDetection/
# !pip install torch 
# !cd /kaggle/working/CNNDetection && pip install -r requirements.txt && bash weights/download_weights.sh && cd /kaggle/working/CNNDetection/examples/realfakedir && rm -r 0_real && rm -r 1_fake && mkdir 0_real && mkdir 1_fake && cp /kaggle/input/spottingdiffusion-testing-dataset/Generated/Generated/* /kaggle/working/CNNDetection/examples/realfakedir/1_fake && cp /kaggle/input/spottingdiffusion-testing-dataset/Real/Real/* /kaggle/working/CNNDetection/examples/realfakedir/0_real/ && cd /kaggle/working/CNNDetection/examples/realfakedir/1_fake && mogrify -resize 256x256! *.png && cd /kaggle/working/CNNDetection/examples/realfakedir/0_real/ && mogrify -resize 256x256! *.png
# !python /kaggle/working/CNNDetection/demo_dir.py -d /kaggle/working/CNNDetection/examples/realfakedir -m /kaggle/working/CNNDetection/weights/blur_jpg_prob0.1.pth
# Out:
# Cloning into 'CNNDetection'...
# remote: Enumerating objects: 632, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 632 (delta 25), reused 25 (delta 25), pack-reused 604
# Receiving objects: 100% (632/632), 6.36 MiB | 18.83 MiB/s, done.
# Resolving deltas: 100% (100/100), done.
# ...
# --2023-08-09 15:43:06--  https://www.dropbox.com/s/2g2jagq2jn1fd0i/blur_jpg_prob0.5.pth?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.18, 2620:100:601f:18::a27d:912
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/2g2jagq2jn1fd0i/blur_jpg_prob0.5.pth [following]
# --2023-08-09 15:43:06--  https://www.dropbox.com/s/raw/2g2jagq2jn1fd0i/blur_jpg_prob0.5.pth
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...
